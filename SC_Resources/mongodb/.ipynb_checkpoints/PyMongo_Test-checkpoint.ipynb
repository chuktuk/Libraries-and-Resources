# %% [markdown]
# # PyMongo Testing Notebook

# %% [markdown]
# > This notebook is a playground for using the MongoDB training database `TrainingDB`.

# %%
# import primary packages needed for exploration
import pymongo
import os
from pymongo import MongoClient

# import pprint, which does a better job of displaying nested JSON objects in python
from pprint import pprint

# %%
# create a connection to MongoClient using a URI string
URI = os.getenv('MONGO_AD_URI')
client = MongoClient(URI)

# %%
# get a database from the connected client
# this db name is database_name
# can also use client['database_name']
db = client.TrainingDB

# %%
# list all collections in the db
db.list_collection_names()
# Out:
# ['PyMongo_Test', 'TrainingDB']

# %%
# create a collection if it doesn't already exist

# adding collation of en_US to help with sorting strings
from pymongo.collation import Collation

# good practice to check for a collection before creating a new one
if 'PyMongo_Test' not in db.list_collection_names():
    collection = db.create_collection('PyMongo_Test', collation=Collation(locale='en_US'))
else:
    print('Collection already exists.')
# Out:
# Collection already exists.

# %%
# connect to a collection
if 'PyMongo_Test' in db.list_collection_names():
    collection = db.PyMongo_Test
else:
    print('Collection does not exist')

# %%
# print the first record from a collection
# returns None if no records exist
pprint(collection.find_one())
# Out:
# None

# %% [markdown]
# ## Preprocessing Data for Inserting Documents to a Collection

# %% [markdown]
# #### Working with XML Data
# - This is sample data generated for proof of concept testing

# %%
# import xml/json packages
import xmltodict
import json

# %%
# set path and file name to read the data
path = './'
file = 'Batch_Req_Report_Sample.xml'
file_path = path + file

# %%
# read the data (result is a string)
with open(file_path) as xml_file:
    my_dict = xmltodict.parse(xml_file.read())
xml_file.close()
json_data = json.dumps(my_dict)
json_data
# Out:
# '{"VisionDataExchange": {"@xmlns:xsi": "http://www.w3.org/2001/XMLSchema-instance", "Credentials": {"Client": "client_rtg_base", "Version": "4.3"}, "ExportData": {"Requisition": {"@clientReqId": "21", "Title": "ReqExportTest", "SalaryLow": "888", "SalaryHigh": "999", "RecruitStartDate": "2008-12-26 00:00:00", "RecruitEndDate": null, "TargetStartDate": "2009-03-03 00:00:00", "CandFillCount": "50", "WorkHours": "40", "WorkHourUnit": "Week", "TravelRequired": {"@code": "1", "#text": "Yes"}, "TravelPercent": "65", "EssentialFunction": "position requirements", "Description": "position description", "WorkEnv": null, "Active": {"@code": "1", "#text": "Yes"}, "FolderActivityDate": "2008-12-22 17:15:46", "Posted": {"@code": "0", "#text": "No"}, "Status": {"@code": "OPEN", "#text": "Open"}, "Workflow": {"@code": "RENE_WK", "#text": "Rene workflow"}, "Priority": {"@code": "MEDIUM", "#text": "Medium Priority"}, "Location": {"@code": "RALEIGH_NC", "#text": "Raleigh, NC"}, "Experience": {"@code": "LESS_THAN_ONE_YEAR", "#text": "Less than 1 year"}, "Duration": {"@code": "FULLTIMEREG", "#text": "Full-Time Regular"}, "Education": {"@code": "ASSOCIATES", "#text": "Associates Degree"}, "FLSA": {"@code": "EXECUTIVE", "#text": "Executive"}, "GradeLevel": {"@code": "NOT_INDICATED", "#text": "Not Indicated"}, "JobCode": {"@code": "NOT_INDICATED", "#text": "Not Indicated"}, "CostCenter": {"@code": "ENTERPRISE", "#text": "Enterprise"}, "SalaryCurrency": {"@code": "USD", "#text": "United States of America, US Dollar"}, "Relocation": {"@code": "NO", "#text": "No"}, "CustomInfo": {"Field": [{"@fldCode": "FLD_REQ_DEPARTMENT", "@code": "MARKETING", "#text": "Cost Accounting"}, {"@fldCode": "FLD_REQ_DIVISION", "@code": "ASIA_PACIFIC", "#text": "Asia Pacific"}, {"@fldCode": "FLD_REQ_POSITION_BUDGETED", "@code": "1", "#text": "Yes"}, {"@fldCode": "FLD_REQ_FACILITY", "@code": "MANUFACTURING", "#text": "Manufacturing Plant"}, {"@fldCode": "FLD_REQ_POSITION_CATEGORY", "@code": "AERO", "#text": "Aerospace"}, {"@fldCode": "FLD_REQ_TARGET_INCENTIVE", "#text": "777"}, {"@fldCode": "FLD_REQ_TARGET_EQUITY", "#text": "666"}, {"@fldCode": "FLD_REQ_OTHER_COMP_INFO", "#text": "Other comp info"}, {"@fldCode": "FLD_REQ_HOURSOFWORK", "#text": "40"}]}, "EEOCategory": {"@code": "PROFESSIONAL", "#text": "Professionals"}, "AAPJobGroup": {"@code": "NOT_INDICATED", "#text": "Not Indicated"}, "AAPEstablishment": {"@code": "NOT_INDICATED", "#text": "Not Indicated"}, "Opening": {"@code": "NEW", "#text": "New Position"}, "Shift": {"@code": "THIRD", "#text": "3rd"}, "OpeningDescription": "reason for opening", "Budgeted": {"@code": "1", "#text": "Yes"}, "Skills": null, "Categories": null, "Contacts": {"Contact": [{"Primary": {"@code": "1", "#text": "Yes"}, "Role": {"@code": "HIRING_MANAGER", "#text": "Hiring Manager"}, "User": {"@refCode": "", "#text": "emmanuel montes h"}}, {"Primary": {"@code": "1", "#text": "Yes"}, "Role": {"@code": "RECRUITER", "#text": "Recruiter"}, "User": {"@refCode": "rene_rec0", "#text": "rene recruiter 0"}}]}, "Costs": {"Cost": {"@id": "4", "Amount": "500", "SubCategory": {"@code": "REFERRALS", "#text": "Employee/Other Referrals"}, "Currency": {"@code": "USD", "#text": "United States of America, US Dollar"}, "Date": "2008-12-22 00:00:00", "Note": "cost note"}}, "Notes": {"Note": [{"@id": "11", "Subject": "note 2", "Text": "this is the note 2 this note is not public", "Public": {"@code": "0", "#text": "No"}, "Created": {"Date": "2008-12-22 17:19:04", "UTCOffset": "-5", "User": {"@refCode": "", "#text": "pc-john.doe"}}, "Modified": {"Date": "2008-12-22 17:19:04", "UTCOffset": "-5", "User": {"@refCode": "", "#text": "pc-john.doe"}}}, {"@id": "10", "Subject": "Note 1", "Text": "Req Note 1", "Public": {"@code": "1", "#text": "Yes"}, "Created": {"Date": "2008-12-22 17:18:46", "UTCOffset": "-5", "User": {"@refCode": "", "#text": "pc-john.doe"}}, "Modified": {"Date": "2008-12-22 17:18:46", "UTCOffset": "-5", "User": {"@refCode": "", "#text": "pc-john.doe"}}}]}, "Appro ...

# %%
# replace null with None so python doesn't freak out
jd = json_data.replace('null', 'None')

# %%
# use the eval function to return a python dictionary in JSON format
jd = eval(jd)
jd
# Out:
# {'VisionDataExchange': {'@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'Credentials': {'Client': 'client_rtg_base', 'Version': '4.3'},
#   'ExportData': {'Requisition': {'@clientReqId': '21',
#     'Title': 'ReqExportTest',
#     'SalaryLow': '888',
#     'SalaryHigh': '999',
#     'RecruitStartDate': '2008-12-26 00:00:00',
#     'RecruitEndDate': None,
#     'TargetStartDate': '2009-03-03 00:00:00',
#     'CandFillCount': '50',
#     'WorkHours': '40',
#     'WorkHourUnit': 'Week',
#     'TravelRequired': {'@code': '1', '#text': 'Yes'},
#     'TravelPercent': '65',
#     'EssentialFunction': 'position requirements',
#     'Description': 'position description',
#     'WorkEnv': None,
#     'Active': {'@code': '1', '#text': 'Yes'},
#     'FolderActivityDate': '2008-12-22 17:15:46',
#     'Posted': {'@code': '0', '#text': 'No'},
#     'Status': {'@code': 'OPEN', '#text': 'Open'},
#     'Workflow': {'@code': 'RENE_WK', '#text': 'Rene workflow'},
#     'Priority': {'@code': 'MEDIUM', '#text': 'Medium Priority'},
#     'Location': {'@code': 'RALEIGH_NC', '#text': 'Raleigh, NC'},
#     'Experience': {'@code': 'LESS_THAN_ONE_YEAR', '#text': 'Less than 1 year'},
#     'Duration': {'@code': 'FULLTIMEREG', '#text': 'Full-Time Regular'},
#     'Education': {'@code': 'ASSOCIATES', '#text': 'Associates Degree'},
#     'FLSA': {'@code': 'EXECUTIVE', '#text': 'Executive'},
#     'GradeLevel': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#     'JobCode': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#     'CostCenter': {'@code': 'ENTERPRISE', '#text': 'Enterprise'},
#     'SalaryCurrency': {'@code': 'USD',
#      '#text': 'United States of America, US Dollar'},
#     'Relocation': {'@code': 'NO', '#text': 'No'},
#     'CustomInfo': {'Field': [{'@fldCode': 'FLD_REQ_DEPARTMENT',
#        '@code': 'MARKETING',
#        '#text': 'Cost Accounting'},
#       {'@fldCode': 'FLD_REQ_DIVISION',
#        '@code': 'ASIA_PACIFIC',
#        '#text': 'Asia Pacific'},
#       {'@fldCode': 'FLD_REQ_POSITION_BUDGETED', '@code': '1', '#text': 'Yes'},
#       {'@fldCode': 'FLD_REQ_FACILITY',
#        '@code': 'MANUFACTURING',
#        '#text': 'Manufacturing Plant'},
#       {'@fldCode': 'FLD_REQ_POSITION_CATEGORY',
#        '@code': 'AERO',
#        '#text': 'Aerospace'},
#       {'@fldCode': 'FLD_REQ_TARGET_INCENTIVE', '#text': '777'},
#       {'@fldCode': 'FLD_REQ_TARGET_EQUITY', '#text': '666'},
#       {'@fldCode': 'FLD_REQ_OTHER_COMP_INFO', '#text': 'Other comp info'},
#       {'@fldCode': 'FLD_REQ_HOURSOFWORK', '#text': '40'}]},
#     'EEOCategory': {'@code': 'PROFESSIONAL', '#text': 'Professionals'},
#     'AAPJobGroup': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#     'AAPEstablishment': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#     'Opening': {'@code': 'NEW', '#text': 'New Position'},
#     'Shift': {'@code': 'THIRD', '#text': '3rd'},
#     'OpeningDescription': 'reason for opening',
#     'Budgeted': {'@code': '1', '#text': 'Yes'},
#     'Skills': None,
#     'Categories': None,
#     'Contacts': {'Contact': [{'Primary': {'@code': '1', '#text': 'Yes'},
#        'Role': {'@code': 'HIRING_MANAGER', '#text': 'Hiring Manager'},
#        'User': {'@refCode': '', '#text': 'emmanuel montes h'}},
#       {'Primary': {'@code': '1', '#text': 'Yes'},
#        'Role': {'@code': 'RECRUITER', '#text': 'Recruiter'},
#        'User': {'@refCode': 'rene_rec0', '#text': 'rene recruiter 0'}}]},
#     'Costs': {'Cost': {'@id': '4',
#       'Amount': '500',
#       'SubCategory': {'@code': 'REFERRALS',
#        '#text': 'Employee/Other Referrals'},
#       'Currency': {'@code': 'USD',
#        '#text': 'United States of America, US Dollar'},
#       'Date': '2008-12-22 00:00:00',
#       'Note': 'cost note'}},
#     'Notes': {'Note': [{'@id': '11',
#        'Subject': 'note 2',
#        'Text': 'this is the note 2 this note is not public',
#        'Public': {'@code': '0', '#text': 'No'},
#        'Created': {'Date': '2008-12-22 17:19:04',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#        'Modified': {'Date': '2008-12-22 17:19:04',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}}},
#       {'@id': '10',
#        'Subject': 'Note 1',
#        'Text': 'Req Note 1',
#        'Public': {'@code': '1', '#text': 'Yes'},
#        'Created': {'Date': '2008-12-22 17:18:46',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#        'Modified': {'Date': '2008-12-22 17:18:46',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}}}]},
#     'Approval': {'Status': {'@code': 'PENDING', '#text': 'Pending'},
#      'Panels': {'Panel': [{'@code': 'PNL_REQ_GENERAL_INFO',
#         '#text': 'Requisition Information'},
#        {'@code': 'PNL_REQ_DETAIL_INFO', '#text': 'Opening Information'},
#        {'@code': 'PNL_REQ_ADDITIONAL_INFO',
#         '#text': 'Additional Information'}]},
#      'Editors': {'User': {'@refCode': 'Editor', '#text': 'Approval Editor'}},
#      'Approvers': {'User': [{'@refCode': 'jdoe',
#         'FullName': 'pc-jane.doe',
#         'Approved': {'@code': '0', '#text': 'No'},
#         'DenialReason': {'@code': ''},
#         'DateSent': '2008-12-22 20:15:47.321',
#         'DateCompleted': None,
#         'IsNextApprover': {'@code': '1', '#text': 'Yes'}},
#        {'@refCode': 'madoe',
#         'FullName': 'pc-mark.doe',
#         'Approved': {'@code': '0', '#text': 'No'},
#         'DenialReason': {'@code': ''},
#         'DateSent': None,
#         'DateCompleted': None,
#         'IsNextApprover': {'@code': '0', '#text': 'No'}}]},
#      'CreateNote': {'@code': '0', '#text': 'No'},
#      'Email': {'@code': 'AFTERME', '#text': 'After Approval'}},
#     'Created': {'Date': '2008-12-22 17:15:46',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#     'Modified': {'Date': '2008-12-22 17:16:33',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#     'ReqStatusActivities': {'ReqStatusActivity': [{'@id': '40',
#        'LogEntryType': {'@code': 'CREATED'},
#        'StatusBefore': {'@code': ''},
#        'StatusAfter': {'@code': ''},
#        'Created': {'Date': '2008-12-22 17:15:47',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}}},
#       {'@id': '41',
#        'LogEntryType': {'@code': 'STATUS_CHANGE'},
#        'StatusBefore': {'@code': 'OPEN', '#text': 'Open'},
#        'StatusAfter': {'@code': 'PENDING_APPROVAL', '#text': 'Pending'},
#        'Created': {'Date': '2008-12-22 17:15:47',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}}},
#       {'@id': '42',
#        'LogEntryType': {'@code': 'STATUS_CHANGE'},
#        'StatusBefore': {'@code': 'PENDING_APPROVAL', '#text': 'Pending'},
#        'StatusAfter': {'@code': 'OPEN', '#text': 'Open'},
#        'Created': {'Date': '2008-12-22 17:16:33',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}}}]},
#     'EntityModifiedOn': '2008-12-22 17:19:26.0',
#     'JobPostActivities': {'JobPost': {'@id': '1',
#       'TemplateName': 'Untitled',
#       'Title': 'ReqExportTest',
#       'SalaryLow': '888',
#       'SalaryHigh': '999',
#       'RecruitStartDate': '2008-12-26 00:00:00',
#       'RecruitEndDate': None,
#       'TargetStartDate': '2009-03-03 00:00:00',
#       'CandFillCount': '1',
#       'WorkHours': '50',
#       'WorkHourUnit': 'Week',
#       'TravelRequired': {'@code': '1', '#text': 'Yes'},
#       'TravelPercent': '65',
#       'EssentialFunction': 'position requirements',
#       'Description': 'position description',
#       'WorkEnv': None,
#       'Location': {'@code': 'RALEIGH_NC', '#text': 'Raleigh, NC'},
#       'Experience': {'@code': 'LESS_THAN_ONE_YEAR',
#        '#text': 'Less than 1 year'},
#       'Duration': {'@code': 'FULLTIMEREG', '#text': 'Full-Time Regular'},
#       'Education': {'@code': 'ASSOCIATES', '#text': 'Associates Degree'},
#       'FLSA': {'@code': 'EXECUTIVE', '#text': 'Executive"'},
#       'GradeLevel': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#       'JobCode': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#       'CostCenter': {'@code': 'ENTERPRISE', '#text': 'Enterprise'},
#       'SalaryCurrency': {'@code': 'USD',
#        '#text': 'United States of America, US Dollar'},
#       'Relocation': {'@code': 'NO', '#text': 'No"'},
#       'Shift': {'@code': 'THIRD', '#text': '3rd"'},
#       'Contact': {'Name': 'James Doe',
#        'Email': 'JamesDoe@a.com',
#        'Phone': None,
#        'Fax': None,
#        'Address': None},
#       'IsOutOfSyncWithReq': {'@code': '0', '#text': 'No'},
#       'ReferralPosition': {'@code': '1', '#text': 'Yes'},
#       'CustomInfo': {'Field': [{'@fldCode': 'FLD_JP_DEPARTMENT',
#          '@code': 'MARKETING',
#          '#text': 'Cost Accounting'},
#         {'@fldCode': 'FLD_JP_DIVISION',
#          '@code': 'ASIA_PACIFIC',
#          '#text': 'Asia Pacific'},
#         {'@fldCode': 'FLD_JP_POSITION_BUDGETED', '@code': '1', '#text': 'Yes'},
#         {'@fldCode': 'FLD_JP_FACILITY',
#          '@code': 'MANUFACTURING',
#          '#text': 'Manufacturing Plant'},
#         {'@fldCode': 'FLD_JP_POSITION_CATEGORY',
#          '@code': 'AERO',
#          '#text': 'Aerospace'},
#         {'@fldCode': 'FLD_JP_TARGET_INCENTIVE', '#text': '777'},
#         {'@fldCode': 'FLD_JP_TARGET_EQUITY', '#text': '666'},
#         {'@fldCode': 'FLD_JP_OTHER_COMP_INFO', '#text': 'Other comp info'},
#         {'@fldCode': 'FLD_JP_HOURSOFWORK', '#text': '40'}]},
#       'JobPostStatusLog': [{'@id': '2',
#         'IsCurrent': {'@code': '1', '#text': 'Yes'},
#         'LogDate': '2009-12-04 11:09:27.0',
#         'PostSite': 'post site',
#         'PostSiteType': 'External',
#         'PostingStatus': 'Removed',
#         'UserAction': 'Remove',
#         'UserStatus': 'Success'},
#        {'@id': '1',
#         'IsCurrent': {'@code': '0', '#text': 'No'},
#         'LogDate': '2009-10-19 13:05:31.0',
#         'PostSite': 'post site2',
#         'PostSiteType': 'External',
#         'PostingStatus': 'Posted',
#         'UserAction': 'Remove',
#         'UserStatus': 'Success'}],
#       'Created': {'Date': '2009-10-19 13:05:30',
#        'UTCOffset': '-5',
#        'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#       'Modified': {'Date': '2009-12-04 11:09:27',
#        'UTCOffset': '-5',
#        'User': {'@refCode': '', '#text': 'pc-john.doe'}}}}}}}}

# %%
# datatype is indeed a python dictionary
type(jd)
# Out:
# dict

# %%
# duplicate the data to simulate a collection of records
data = [jd, jd, jd, jd, jd, jd]

# %%
# verify data
type(data)
# Out:
# list

# %%
# verify that 'data' is a list of dictionaries, each representing a record
data[4]
# Out:
# {'VisionDataExchange': {'@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'Credentials': {'Client': 'client_rtg_base', 'Version': '4.3'},
#   'ExportData': {'Requisition': {'@clientReqId': '21',
#     'Title': 'ReqExportTest',
#     'SalaryLow': '888',
#     'SalaryHigh': '999',
#     'RecruitStartDate': '2008-12-26 00:00:00',
#     'RecruitEndDate': None,
#     'TargetStartDate': '2009-03-03 00:00:00',
#     'CandFillCount': '50',
#     'WorkHours': '40',
#     'WorkHourUnit': 'Week',
#     'TravelRequired': {'@code': '1', '#text': 'Yes'},
#     'TravelPercent': '65',
#     'EssentialFunction': 'position requirements',
#     'Description': 'position description',
#     'WorkEnv': None,
#     'Active': {'@code': '1', '#text': 'Yes'},
#     'FolderActivityDate': '2008-12-22 17:15:46',
#     'Posted': {'@code': '0', '#text': 'No'},
#     'Status': {'@code': 'OPEN', '#text': 'Open'},
#     'Workflow': {'@code': 'RENE_WK', '#text': 'Rene workflow'},
#     'Priority': {'@code': 'MEDIUM', '#text': 'Medium Priority'},
#     'Location': {'@code': 'RALEIGH_NC', '#text': 'Raleigh, NC'},
#     'Experience': {'@code': 'LESS_THAN_ONE_YEAR', '#text': 'Less than 1 year'},
#     'Duration': {'@code': 'FULLTIMEREG', '#text': 'Full-Time Regular'},
#     'Education': {'@code': 'ASSOCIATES', '#text': 'Associates Degree'},
#     'FLSA': {'@code': 'EXECUTIVE', '#text': 'Executive'},
#     'GradeLevel': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#     'JobCode': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#     'CostCenter': {'@code': 'ENTERPRISE', '#text': 'Enterprise'},
#     'SalaryCurrency': {'@code': 'USD',
#      '#text': 'United States of America, US Dollar'},
#     'Relocation': {'@code': 'NO', '#text': 'No'},
#     'CustomInfo': {'Field': [{'@fldCode': 'FLD_REQ_DEPARTMENT',
#        '@code': 'MARKETING',
#        '#text': 'Cost Accounting'},
#       {'@fldCode': 'FLD_REQ_DIVISION',
#        '@code': 'ASIA_PACIFIC',
#        '#text': 'Asia Pacific'},
#       {'@fldCode': 'FLD_REQ_POSITION_BUDGETED', '@code': '1', '#text': 'Yes'},
#       {'@fldCode': 'FLD_REQ_FACILITY',
#        '@code': 'MANUFACTURING',
#        '#text': 'Manufacturing Plant'},
#       {'@fldCode': 'FLD_REQ_POSITION_CATEGORY',
#        '@code': 'AERO',
#        '#text': 'Aerospace'},
#       {'@fldCode': 'FLD_REQ_TARGET_INCENTIVE', '#text': '777'},
#       {'@fldCode': 'FLD_REQ_TARGET_EQUITY', '#text': '666'},
#       {'@fldCode': 'FLD_REQ_OTHER_COMP_INFO', '#text': 'Other comp info'},
#       {'@fldCode': 'FLD_REQ_HOURSOFWORK', '#text': '40'}]},
#     'EEOCategory': {'@code': 'PROFESSIONAL', '#text': 'Professionals'},
#     'AAPJobGroup': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#     'AAPEstablishment': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#     'Opening': {'@code': 'NEW', '#text': 'New Position'},
#     'Shift': {'@code': 'THIRD', '#text': '3rd'},
#     'OpeningDescription': 'reason for opening',
#     'Budgeted': {'@code': '1', '#text': 'Yes'},
#     'Skills': None,
#     'Categories': None,
#     'Contacts': {'Contact': [{'Primary': {'@code': '1', '#text': 'Yes'},
#        'Role': {'@code': 'HIRING_MANAGER', '#text': 'Hiring Manager'},
#        'User': {'@refCode': '', '#text': 'emmanuel montes h'}},
#       {'Primary': {'@code': '1', '#text': 'Yes'},
#        'Role': {'@code': 'RECRUITER', '#text': 'Recruiter'},
#        'User': {'@refCode': 'rene_rec0', '#text': 'rene recruiter 0'}}]},
#     'Costs': {'Cost': {'@id': '4',
#       'Amount': '500',
#       'SubCategory': {'@code': 'REFERRALS',
#        '#text': 'Employee/Other Referrals'},
#       'Currency': {'@code': 'USD',
#        '#text': 'United States of America, US Dollar'},
#       'Date': '2008-12-22 00:00:00',
#       'Note': 'cost note'}},
#     'Notes': {'Note': [{'@id': '11',
#        'Subject': 'note 2',
#        'Text': 'this is the note 2 this note is not public',
#        'Public': {'@code': '0', '#text': 'No'},
#        'Created': {'Date': '2008-12-22 17:19:04',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#        'Modified': {'Date': '2008-12-22 17:19:04',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}}},
#       {'@id': '10',
#        'Subject': 'Note 1',
#        'Text': 'Req Note 1',
#        'Public': {'@code': '1', '#text': 'Yes'},
#        'Created': {'Date': '2008-12-22 17:18:46',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#        'Modified': {'Date': '2008-12-22 17:18:46',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}}}]},
#     'Approval': {'Status': {'@code': 'PENDING', '#text': 'Pending'},
#      'Panels': {'Panel': [{'@code': 'PNL_REQ_GENERAL_INFO',
#         '#text': 'Requisition Information'},
#        {'@code': 'PNL_REQ_DETAIL_INFO', '#text': 'Opening Information'},
#        {'@code': 'PNL_REQ_ADDITIONAL_INFO',
#         '#text': 'Additional Information'}]},
#      'Editors': {'User': {'@refCode': 'Editor', '#text': 'Approval Editor'}},
#      'Approvers': {'User': [{'@refCode': 'jdoe',
#         'FullName': 'pc-jane.doe',
#         'Approved': {'@code': '0', '#text': 'No'},
#         'DenialReason': {'@code': ''},
#         'DateSent': '2008-12-22 20:15:47.321',
#         'DateCompleted': None,
#         'IsNextApprover': {'@code': '1', '#text': 'Yes'}},
#        {'@refCode': 'madoe',
#         'FullName': 'pc-mark.doe',
#         'Approved': {'@code': '0', '#text': 'No'},
#         'DenialReason': {'@code': ''},
#         'DateSent': None,
#         'DateCompleted': None,
#         'IsNextApprover': {'@code': '0', '#text': 'No'}}]},
#      'CreateNote': {'@code': '0', '#text': 'No'},
#      'Email': {'@code': 'AFTERME', '#text': 'After Approval'}},
#     'Created': {'Date': '2008-12-22 17:15:46',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#     'Modified': {'Date': '2008-12-22 17:16:33',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#     'ReqStatusActivities': {'ReqStatusActivity': [{'@id': '40',
#        'LogEntryType': {'@code': 'CREATED'},
#        'StatusBefore': {'@code': ''},
#        'StatusAfter': {'@code': ''},
#        'Created': {'Date': '2008-12-22 17:15:47',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}}},
#       {'@id': '41',
#        'LogEntryType': {'@code': 'STATUS_CHANGE'},
#        'StatusBefore': {'@code': 'OPEN', '#text': 'Open'},
#        'StatusAfter': {'@code': 'PENDING_APPROVAL', '#text': 'Pending'},
#        'Created': {'Date': '2008-12-22 17:15:47',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}}},
#       {'@id': '42',
#        'LogEntryType': {'@code': 'STATUS_CHANGE'},
#        'StatusBefore': {'@code': 'PENDING_APPROVAL', '#text': 'Pending'},
#        'StatusAfter': {'@code': 'OPEN', '#text': 'Open'},
#        'Created': {'Date': '2008-12-22 17:16:33',
#         'UTCOffset': '-5',
#         'User': {'@refCode': '', '#text': 'pc-john.doe'}}}]},
#     'EntityModifiedOn': '2008-12-22 17:19:26.0',
#     'JobPostActivities': {'JobPost': {'@id': '1',
#       'TemplateName': 'Untitled',
#       'Title': 'ReqExportTest',
#       'SalaryLow': '888',
#       'SalaryHigh': '999',
#       'RecruitStartDate': '2008-12-26 00:00:00',
#       'RecruitEndDate': None,
#       'TargetStartDate': '2009-03-03 00:00:00',
#       'CandFillCount': '1',
#       'WorkHours': '50',
#       'WorkHourUnit': 'Week',
#       'TravelRequired': {'@code': '1', '#text': 'Yes'},
#       'TravelPercent': '65',
#       'EssentialFunction': 'position requirements',
#       'Description': 'position description',
#       'WorkEnv': None,
#       'Location': {'@code': 'RALEIGH_NC', '#text': 'Raleigh, NC'},
#       'Experience': {'@code': 'LESS_THAN_ONE_YEAR',
#        '#text': 'Less than 1 year'},
#       'Duration': {'@code': 'FULLTIMEREG', '#text': 'Full-Time Regular'},
#       'Education': {'@code': 'ASSOCIATES', '#text': 'Associates Degree'},
#       'FLSA': {'@code': 'EXECUTIVE', '#text': 'Executive"'},
#       'GradeLevel': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#       'JobCode': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#       'CostCenter': {'@code': 'ENTERPRISE', '#text': 'Enterprise'},
#       'SalaryCurrency': {'@code': 'USD',
#        '#text': 'United States of America, US Dollar'},
#       'Relocation': {'@code': 'NO', '#text': 'No"'},
#       'Shift': {'@code': 'THIRD', '#text': '3rd"'},
#       'Contact': {'Name': 'James Doe',
#        'Email': 'JamesDoe@a.com',
#        'Phone': None,
#        'Fax': None,
#        'Address': None},
#       'IsOutOfSyncWithReq': {'@code': '0', '#text': 'No'},
#       'ReferralPosition': {'@code': '1', '#text': 'Yes'},
#       'CustomInfo': {'Field': [{'@fldCode': 'FLD_JP_DEPARTMENT',
#          '@code': 'MARKETING',
#          '#text': 'Cost Accounting'},
#         {'@fldCode': 'FLD_JP_DIVISION',
#          '@code': 'ASIA_PACIFIC',
#          '#text': 'Asia Pacific'},
#         {'@fldCode': 'FLD_JP_POSITION_BUDGETED', '@code': '1', '#text': 'Yes'},
#         {'@fldCode': 'FLD_JP_FACILITY',
#          '@code': 'MANUFACTURING',
#          '#text': 'Manufacturing Plant'},
#         {'@fldCode': 'FLD_JP_POSITION_CATEGORY',
#          '@code': 'AERO',
#          '#text': 'Aerospace'},
#         {'@fldCode': 'FLD_JP_TARGET_INCENTIVE', '#text': '777'},
#         {'@fldCode': 'FLD_JP_TARGET_EQUITY', '#text': '666'},
#         {'@fldCode': 'FLD_JP_OTHER_COMP_INFO', '#text': 'Other comp info'},
#         {'@fldCode': 'FLD_JP_HOURSOFWORK', '#text': '40'}]},
#       'JobPostStatusLog': [{'@id': '2',
#         'IsCurrent': {'@code': '1', '#text': 'Yes'},
#         'LogDate': '2009-12-04 11:09:27.0',
#         'PostSite': 'post site',
#         'PostSiteType': 'External',
#         'PostingStatus': 'Removed',
#         'UserAction': 'Remove',
#         'UserStatus': 'Success'},
#        {'@id': '1',
#         'IsCurrent': {'@code': '0', '#text': 'No'},
#         'LogDate': '2009-10-19 13:05:31.0',
#         'PostSite': 'post site2',
#         'PostSiteType': 'External',
#         'PostingStatus': 'Posted',
#         'UserAction': 'Remove',
#         'UserStatus': 'Success'}],
#       'Created': {'Date': '2009-10-19 13:05:30',
#        'UTCOffset': '-5',
#        'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#       'Modified': {'Date': '2009-12-04 11:09:27',
#        'UTCOffset': '-5',
#        'User': {'@refCode': '', '#text': 'pc-john.doe'}}}}}}}}

# %%
# remove the unneccessary first few levels
def get_data(data):
    return [i['VisionDataExchange']['ExportData']['Requisition'] for i in data]

# %%
# run function, check results
data = get_data(data)
data[0]
# Out:
# {'@clientReqId': '21',
#  'Title': 'ReqExportTest',
#  'SalaryLow': '888',
#  'SalaryHigh': '999',
#  'RecruitStartDate': '2008-12-26 00:00:00',
#  'RecruitEndDate': None,
#  'TargetStartDate': '2009-03-03 00:00:00',
#  'CandFillCount': '50',
#  'WorkHours': '40',
#  'WorkHourUnit': 'Week',
#  'TravelRequired': {'@code': '1', '#text': 'Yes'},
#  'TravelPercent': '65',
#  'EssentialFunction': 'position requirements',
#  'Description': 'position description',
#  'WorkEnv': None,
#  'Active': {'@code': '1', '#text': 'Yes'},
#  'FolderActivityDate': '2008-12-22 17:15:46',
#  'Posted': {'@code': '0', '#text': 'No'},
#  'Status': {'@code': 'OPEN', '#text': 'Open'},
#  'Workflow': {'@code': 'RENE_WK', '#text': 'Rene workflow'},
#  'Priority': {'@code': 'MEDIUM', '#text': 'Medium Priority'},
#  'Location': {'@code': 'RALEIGH_NC', '#text': 'Raleigh, NC'},
#  'Experience': {'@code': 'LESS_THAN_ONE_YEAR', '#text': 'Less than 1 year'},
#  'Duration': {'@code': 'FULLTIMEREG', '#text': 'Full-Time Regular'},
#  'Education': {'@code': 'ASSOCIATES', '#text': 'Associates Degree'},
#  'FLSA': {'@code': 'EXECUTIVE', '#text': 'Executive'},
#  'GradeLevel': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#  'JobCode': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#  'CostCenter': {'@code': 'ENTERPRISE', '#text': 'Enterprise'},
#  'SalaryCurrency': {'@code': 'USD',
#   '#text': 'United States of America, US Dollar'},
#  'Relocation': {'@code': 'NO', '#text': 'No'},
#  'CustomInfo': {'Field': [{'@fldCode': 'FLD_REQ_DEPARTMENT',
#     '@code': 'MARKETING',
#     '#text': 'Cost Accounting'},
#    {'@fldCode': 'FLD_REQ_DIVISION',
#     '@code': 'ASIA_PACIFIC',
#     '#text': 'Asia Pacific'},
#    {'@fldCode': 'FLD_REQ_POSITION_BUDGETED', '@code': '1', '#text': 'Yes'},
#    {'@fldCode': 'FLD_REQ_FACILITY',
#     '@code': 'MANUFACTURING',
#     '#text': 'Manufacturing Plant'},
#    {'@fldCode': 'FLD_REQ_POSITION_CATEGORY',
#     '@code': 'AERO',
#     '#text': 'Aerospace'},
#    {'@fldCode': 'FLD_REQ_TARGET_INCENTIVE', '#text': '777'},
#    {'@fldCode': 'FLD_REQ_TARGET_EQUITY', '#text': '666'},
#    {'@fldCode': 'FLD_REQ_OTHER_COMP_INFO', '#text': 'Other comp info'},
#    {'@fldCode': 'FLD_REQ_HOURSOFWORK', '#text': '40'}]},
#  'EEOCategory': {'@code': 'PROFESSIONAL', '#text': 'Professionals'},
#  'AAPJobGroup': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#  'AAPEstablishment': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#  'Opening': {'@code': 'NEW', '#text': 'New Position'},
#  'Shift': {'@code': 'THIRD', '#text': '3rd'},
#  'OpeningDescription': 'reason for opening',
#  'Budgeted': {'@code': '1', '#text': 'Yes'},
#  'Skills': None,
#  'Categories': None,
#  'Contacts': {'Contact': [{'Primary': {'@code': '1', '#text': 'Yes'},
#     'Role': {'@code': 'HIRING_MANAGER', '#text': 'Hiring Manager'},
#     'User': {'@refCode': '', '#text': 'emmanuel montes h'}},
#    {'Primary': {'@code': '1', '#text': 'Yes'},
#     'Role': {'@code': 'RECRUITER', '#text': 'Recruiter'},
#     'User': {'@refCode': 'rene_rec0', '#text': 'rene recruiter 0'}}]},
#  'Costs': {'Cost': {'@id': '4',
#    'Amount': '500',
#    'SubCategory': {'@code': 'REFERRALS', '#text': 'Employee/Other Referrals'},
#    'Currency': {'@code': 'USD',
#     '#text': 'United States of America, US Dollar'},
#    'Date': '2008-12-22 00:00:00',
#    'Note': 'cost note'}},
#  'Notes': {'Note': [{'@id': '11',
#     'Subject': 'note 2',
#     'Text': 'this is the note 2 this note is not public',
#     'Public': {'@code': '0', '#text': 'No'},
#     'Created': {'Date': '2008-12-22 17:19:04',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#     'Modified': {'Date': '2008-12-22 17:19:04',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}}},
#    {'@id': '10',
#     'Subject': 'Note 1',
#     'Text': 'Req Note 1',
#     'Public': {'@code': '1', '#text': 'Yes'},
#     'Created': {'Date': '2008-12-22 17:18:46',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#     'Modified': {'Date': '2008-12-22 17:18:46',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}}}]},
#  'Approval': {'Status': {'@code': 'PENDING', '#text': 'Pending'},
#   'Panels': {'Panel': [{'@code': 'PNL_REQ_GENERAL_INFO',
#      '#text': 'Requisition Information'},
#     {'@code': 'PNL_REQ_DETAIL_INFO', '#text': 'Opening Information'},
#     {'@code': 'PNL_REQ_ADDITIONAL_INFO', '#text': 'Additional Information'}]},
#   'Editors': {'User': {'@refCode': 'Editor', '#text': 'Approval Editor'}},
#   'Approvers': {'User': [{'@refCode': 'jdoe',
#      'FullName': 'pc-jane.doe',
#      'Approved': {'@code': '0', '#text': 'No'},
#      'DenialReason': {'@code': ''},
#      'DateSent': '2008-12-22 20:15:47.321',
#      'DateCompleted': None,
#      'IsNextApprover': {'@code': '1', '#text': 'Yes'}},
#     {'@refCode': 'madoe',
#      'FullName': 'pc-mark.doe',
#      'Approved': {'@code': '0', '#text': 'No'},
#      'DenialReason': {'@code': ''},
#      'DateSent': None,
#      'DateCompleted': None,
#      'IsNextApprover': {'@code': '0', '#text': 'No'}}]},
#   'CreateNote': {'@code': '0', '#text': 'No'},
#   'Email': {'@code': 'AFTERME', '#text': 'After Approval'}},
#  'Created': {'Date': '2008-12-22 17:15:46',
#   'UTCOffset': '-5',
#   'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#  'Modified': {'Date': '2008-12-22 17:16:33',
#   'UTCOffset': '-5',
#   'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#  'ReqStatusActivities': {'ReqStatusActivity': [{'@id': '40',
#     'LogEntryType': {'@code': 'CREATED'},
#     'StatusBefore': {'@code': ''},
#     'StatusAfter': {'@code': ''},
#     'Created': {'Date': '2008-12-22 17:15:47',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}}},
#    {'@id': '41',
#     'LogEntryType': {'@code': 'STATUS_CHANGE'},
#     'StatusBefore': {'@code': 'OPEN', '#text': 'Open'},
#     'StatusAfter': {'@code': 'PENDING_APPROVAL', '#text': 'Pending'},
#     'Created': {'Date': '2008-12-22 17:15:47',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}}},
#    {'@id': '42',
#     'LogEntryType': {'@code': 'STATUS_CHANGE'},
#     'StatusBefore': {'@code': 'PENDING_APPROVAL', '#text': 'Pending'},
#     'StatusAfter': {'@code': 'OPEN', '#text': 'Open'},
#     'Created': {'Date': '2008-12-22 17:16:33',
#      'UTCOffset': '-5',
#      'User': {'@refCode': '', '#text': 'pc-john.doe'}}}]},
#  'EntityModifiedOn': '2008-12-22 17:19:26.0',
#  'JobPostActivities': {'JobPost': {'@id': '1',
#    'TemplateName': 'Untitled',
#    'Title': 'ReqExportTest',
#    'SalaryLow': '888',
#    'SalaryHigh': '999',
#    'RecruitStartDate': '2008-12-26 00:00:00',
#    'RecruitEndDate': None,
#    'TargetStartDate': '2009-03-03 00:00:00',
#    'CandFillCount': '1',
#    'WorkHours': '50',
#    'WorkHourUnit': 'Week',
#    'TravelRequired': {'@code': '1', '#text': 'Yes'},
#    'TravelPercent': '65',
#    'EssentialFunction': 'position requirements',
#    'Description': 'position description',
#    'WorkEnv': None,
#    'Location': {'@code': 'RALEIGH_NC', '#text': 'Raleigh, NC'},
#    'Experience': {'@code': 'LESS_THAN_ONE_YEAR', '#text': 'Less than 1 year'},
#    'Duration': {'@code': 'FULLTIMEREG', '#text': 'Full-Time Regular'},
#    'Education': {'@code': 'ASSOCIATES', '#text': 'Associates Degree'},
#    'FLSA': {'@code': 'EXECUTIVE', '#text': 'Executive"'},
#    'GradeLevel': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#    'JobCode': {'@code': 'NOT_INDICATED', '#text': 'Not Indicated'},
#    'CostCenter': {'@code': 'ENTERPRISE', '#text': 'Enterprise'},
#    'SalaryCurrency': {'@code': 'USD',
#     '#text': 'United States of America, US Dollar'},
#    'Relocation': {'@code': 'NO', '#text': 'No"'},
#    'Shift': {'@code': 'THIRD', '#text': '3rd"'},
#    'Contact': {'Name': 'James Doe',
#     'Email': 'JamesDoe@a.com',
#     'Phone': None,
#     'Fax': None,
#     'Address': None},
#    'IsOutOfSyncWithReq': {'@code': '0', '#text': 'No'},
#    'ReferralPosition': {'@code': '1', '#text': 'Yes'},
#    'CustomInfo': {'Field': [{'@fldCode': 'FLD_JP_DEPARTMENT',
#       '@code': 'MARKETING',
#       '#text': 'Cost Accounting'},
#      {'@fldCode': 'FLD_JP_DIVISION',
#       '@code': 'ASIA_PACIFIC',
#       '#text': 'Asia Pacific'},
#      {'@fldCode': 'FLD_JP_POSITION_BUDGETED', '@code': '1', '#text': 'Yes'},
#      {'@fldCode': 'FLD_JP_FACILITY',
#       '@code': 'MANUFACTURING',
#       '#text': 'Manufacturing Plant'},
#      {'@fldCode': 'FLD_JP_POSITION_CATEGORY',
#       '@code': 'AERO',
#       '#text': 'Aerospace'},
#      {'@fldCode': 'FLD_JP_TARGET_INCENTIVE', '#text': '777'},
#      {'@fldCode': 'FLD_JP_TARGET_EQUITY', '#text': '666'},
#      {'@fldCode': 'FLD_JP_OTHER_COMP_INFO', '#text': 'Other comp info'},
#      {'@fldCode': 'FLD_JP_HOURSOFWORK', '#text': '40'}]},
#    'JobPostStatusLog': [{'@id': '2',
#      'IsCurrent': {'@code': '1', '#text': 'Yes'},
#      'LogDate': '2009-12-04 11:09:27.0',
#      'PostSite': 'post site',
#      'PostSiteType': 'External',
#      'PostingStatus': 'Removed',
#      'UserAction': 'Remove',
#      'UserStatus': 'Success'},
#     {'@id': '1',
#      'IsCurrent': {'@code': '0', '#text': 'No'},
#      'LogDate': '2009-10-19 13:05:31.0',
#      'PostSite': 'post site2',
#      'PostSiteType': 'External',
#      'PostingStatus': 'Posted',
#      'UserAction': 'Remove',
#      'UserStatus': 'Success'}],
#    'Created': {'Date': '2009-10-19 13:05:30',
#     'UTCOffset': '-5',
#     'User': {'@refCode': '', '#text': 'pc-john.doe'}},
#    'Modified': {'Date': '2009-12-04 11:09:27',
#     'UTCOffset': '-5',
#     'User': {'@refCode': '', '#text': 'pc-john.doe'}}}}}

# %% [markdown]
# ## Modifying Datatypes on a Set of Records
# - The dictionary 'data' represents an XML data export that is realistic
# - The goal of this section is to convert datatypes from all strings to appropriate types prior to inserting in MongoDB
#     - This particular example really only includes `int` and `datetime` datatypes
#     - Also creating Month, Year, and YYYYMM fields

# %%
# import relevant packages
from datetime import datetime as dt

# %%
data[0]['Created']['Date']
# Out:
# '2008-12-22 17:15:46'

# %%
def convert_add_dates(data):
    '''This function accepts '''
